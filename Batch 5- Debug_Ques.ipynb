# %%
from tensorflow.keras.applications import VGG16
model = VGG16(weights='imagenet', include_top=False, input_shape=(128, 128))  # Missing 3rd channel
# channel dimension missing we need to add 3 for rgb

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Initialize the ImageDataGenerator
datagen = ImageDataGenerator(rescale=1./255)

# Load images from directory with no class labels
train = datagen.flow_from_directory(
    "D:\\Hope AI\\Quiz Community\\Deep Learning\\dataset",  # Ensure double backslashes
    target_=(224, 224),
    class_mode=None,
    batch_size=32,
    shuffle=False
)

# Concluding print statement
print(f"✅ Successfully loaded {len(test.filenames)} images from the dataset folder (no class labels). Ready for inference or feature extraction!")
# wrong parameter name target. we need to use target_size=(224,224)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       4 datagen = ImageDataGenerator(rescale=1./255)
#       6 # Load images from directory with no class labels
# ----> 7 train = datagen.flow_from_directory(
#       8     "D:\\Hope AI\\Quiz Community\\Deep Learning\\dataset",  # Ensure double backslashes
#       9     target_=(224, 224),
#      10     class_mode=None,
#      11     batch_size=32,
#      12     shuffle=False
#      13 )
#      15 # Concluding print statement
#      16 print(f"✅ Successfully loaded {len(test.filenames)} images from the dataset folder (no class labels). Ready for inference or feature extraction!")
#
# TypeError: ImageDataGenerator.flow_from_directory() got an unexpected keyword argument 'target_'

# %%
from tensorflow.keras.applications import MobileNetV2

# Load the base model with pretrained weights
base_model = MobileNetV2(weight='imgenet', include_top=False)

# ❌ Bug: Accidentally setting the whole model to trainable
base_model.trainable = True

# Concluding print statement
trainable_count = len([layer for layer in base_model.layers if layer.trainable])
print(f"⚠️ All {trainable_count} layers in MobileNetV2 are currently trainable. This may lead to overfitting or long training time.")
# spelling error weight='imagenet'. we need to use weights='imagenet'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 4
#       1 from tensorflow.keras.applications import MobileNetV2
#       3 # Load the base model with pretrained weights
# ----> 4 base_model = MobileNetV2(weight='imgenet', include_top=False)
#       6 # ❌ Bug: Accidentally setting the whole model to trainable
#       7 base_model.trainable = True
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/keras/applications/mobilenet_v2.py:199, in MobileNetV2(input_shape, alpha, include_top, weights, input_tensor, pooling, classes, classifier_activation, **kwargs)
#     197     layers = VersionAwareLayers()
#     198 if kwargs:
# --> 199     raise ValueError(f"Unknown argument(s): {kwargs}")
#     200 if not (weights in {"imagenet", None} or tf.io.gfile.exists(weights)):
#     201     raise ValueError(
# ...

# %%
import tensorflow as tf

# Simple model definition
model = tf.keras.Sequential([
    tf.keras.layers.Dense(10, activation='relu', input_shape=(20,)),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy')

# ❌ Bug: Saving model without specifying a file extension

tf.save('my_model.h5')  # Missing '.h5' or '.keras'
print(" Model saved successfully as 'my_model.h5'. You can now load and reuse it later.")
#instead of tf.save, we can use model.save('file.h5')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 13
#       9 model.compile(optimizer='adam', loss='binary_crossentropy')
#      11 # ❌ Bug: Saving model without specifying a file extension
# ---> 13 tf.save('my_model.h5')  # Missing '.h5' or '.keras'
#      14 print(" Model saved successfully as 'my_model.h5'. You can now load and reuse it later.")
#
# AttributeError: module 'tensorflow' has no attribute 'save'

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(100, 100))  # Wrong shape
model = Sequential([
        Flatten(),
        Dense(1, activation='sigmoid')
    ])
print("Model created.")
#input shape error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 4
#       2 from tensorflow.keras.models import Sequential
#       3 from tensorflow.keras.layers import Dense, Flatten
# ----> 4 base_model = VGG16(weights='imagenet', include_top=False, input_shape=(100, 100))  # Wrong shape
#       5 model = Sequential([
#       6         Flatten(),
#       7         Dense(1, activation='sigmoid')
#       8     ])
#       9 print("Model created.")
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/keras/applications/vgg16.py:137, in VGG16(include_top, weights, input_tensor, input_shape, pooling, classes, classifier_activation)
#     131     raise ValueError(
#     132         'If using `weights` as `"imagenet"` with `include_top` '
#     133         "as true, `classes` should be 1000.  "
#     134         f"Received `classes={classes}`"
#     135     )
# ...

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense
import numpy as np

X_dummy = np.random.rand(10, 224, 224, 3)
y_dummy = np.random.randint(0, 2, size=(10,))

base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False

model = Sequential([
    base_model,
    Flatten(),
    Dense(1, activation='sigmoid')
])

model.fit(X_dummy, y_dummy, epochs=1)  # Forgot to compile
# we can model.compile() we can add model.compile() before model.fit()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[41], line 18
#      10 base_model.trainable = False
#      12 model = Sequential([
#      13     base_model,
#      14     Flatten(),
#      15     Dense(1, activation='sigmoid')
#      16 ])
# ---> 18 model.fit(X_dummy, y_dummy, epochs=1)
#
# File ~\anaconda3\envs\deepL\Lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\envs\deepL\Lib\site-packages\keras\engine\training.py:3685, in Model._assert_compile_was_called(self)
# ...

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.preprocessing import image
import numpy as np

model = ResNet50(weights='imagenet')
img = image.load_img("tiger.jpg", target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
is_preprocessed = False
if not is_preprocessed:
    raise ValueError("❌ Image not preprocessed!")

preds = model.predict(img_array)  # No preprocessing
print("✅ Prediction done:", decode_predictions(preds, top=1)[0])
# loss mismatch
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 11
#       9 is_preprocessed = False
#      10 if not is_preprocessed:
# ---> 11     raise ValueError("❌ Image not preprocessed!")
#      13 preds = model.predict(img_array)  # No preprocessing
#      14 print("✅ Prediction done:", decode_predictions(preds, top=1)[0])
#
# ValueError: ❌ Image not preprocessed!

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np

# Sample data
X_train = np.random.random((100, 20))
y_train = np.random.randint(0, 5, (100,))  # Integer-encoded labels

# Model definition
model = Sequential([
    Dense(64, activation='relu', input_shape=(20,)),
    Dense(5, activation='softmax')
])

# Compiling the model with categorical_crossentropy
model.compile(optimizer='adam', loss='categorical_crossentropy')

# This will raise an error because y_train is not one-hot encoded
model.fit(X_train, y_train, epochs=10)
#we can use sparse_categorical_crossentropy
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 20
#      17 model.compile(optimizer='adam', loss='categorical_crossentropy')
#      19 # This will raise an error because y_train is not one-hot encoded
# ---> 20 model.fit(X_train, y_train, epochs=10)
#
# File ~\anaconda3\envs\deepL\Lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Temp\__autograph_generated_fileslz2myl4.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
# ...

# %%
import tensorflow as tf
from tensorflow.keras.layers import Drop
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Small dataset
X_train = np.random.random((10, 50))
y_train = np.random.randint(0, 2, (10,))
# Simplified model with dropout
model = Sequential([
    Dense(128, activation='relu', input_shape=(50,)),
    Dropout(0.5),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy')
model.fit(X_train, y_train, epochs=100)
# we can use dropout for import
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[57], line 2
#       1 import tensorflow as tf
# ----> 2 from tensorflow.keras.layers import Drop
#       3 from tensorflow.keras.models import Sequential
#       4 from tensorflow.keras.layers import Dense
#
# ImportError: cannot import name 'Drop' from 'tensorflow.keras.layers' (C:\Users\Admin\anaconda3\envs\deepL\Lib\site-packages\keras\api\_v2\keras\layers\__init__.py)

# %%
# Load and resize image
from tensorflow.keras.preprocessing import image

img = image.load_img('flower.jpg', target_size=(224, 224))
img_array = image.img_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = img_array / 255.0
plt.imshow(img)
#we can use img_to_array()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[69], line 5
#       2 from tensorflow.keras.preprocessing import image
#       4 img = image.load_img('flower.jpg', target_size=(224, 224))
# ----> 5 img_array = image.img_array(img)
#       6 img_array = np.expand_dims(img_array, axis=0)
#       7 img_array = img_array / 255.0
#
# AttributeError: module 'tensorflow.keras.preprocessing.image' has no attribute 'img_array'

# %%
# Resize image to the target size expected by the model
from tensorflow.keras.preprocessing import image

img = image.load_img('flower.jpg', target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
#we can use img_to_array()
# Now the prediction will work without shape mismatch errors
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[64], line 9
#       6 img_array = np.expand_dims(img_array, axis=0)
#       8 # Now the prediction will work without shape mismatch errors
# ----> 9 model.predict(img_array)
#
# File ~\anaconda3\envs\deepL\Lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Temp\__autograph_generated_file6_zcrwno.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__predict_function(iterator)
#      13 try:
#      14     do_return = True
# ...
