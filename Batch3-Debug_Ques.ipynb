# %%
# Incorrect Import
import tensorflow as tf
#from tensorflow import keras.layers  # ❌ Error: Incorrect module import
from tensorflow import keras
model = tf.keras.Sequential([
    keras.layers.Dense(64, activation='relu', input_shape=(10,)),
    keras.layers.Dense(1, activation='sigmoid')
])
# Out:
# 2026-01-07 09:23:59.556872: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /Users/harikrishnan/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/keras/src/export/tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# /Users/harikrishnan/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

X_train = np.random.rand(100, 10)
#y_train = np.random.randint(0, 2, size=(100, 2))  # ❌ Error: y_train shape mismatch
y_train=np.random.randint(0,2,size=(100,))
model = tf.keras.Sequential([
    layers.Dense(32, activation='relu', input_shape=(10,)),
    layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(train, y_train, epochs=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 14
#       8 model = tf.keras.Sequential([
#       9     layers.Dense(32, activation='relu', input_shape=(10,)),
#      10     layers.Dense(1, activation='sigmoid')
#      11 ])
#      13 model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# ---> 14 model.fit(train, y_train, epochs=5)
#
# NameError: name 'train' is not defined

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import Adam  # ❌ Wrong import method in newer versions

opt = Adam(lr=0.001, decay=0.0001)  # ❌ Error: 'decay' parameter is deprecated
# we can use legacy namespace using same argument using same code
# Out:
# /Users/harikrishnan/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/keras/src/optimizers/base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 4
#       1 import tensorflow as tf
#       2 from tensorflow.keras.optimizers import Adam  # ❌ Wrong import method in newer versions
# ----> 4 opt = Adam(lr=0.001, decay=0.0001)
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/keras/src/optimizers/adam.py:62, in Adam.__init__(self, learning_rate, beta_1, beta_2, epsilon, amsgrad, weight_decay, clipnorm, clipvalue, global_clipnorm, use_ema, ema_momentum, ema_overwrite_frequency, loss_scale_factor, gradient_accumulation_steps, name, **kwargs)
#      43 def __init__(
#      44     self,
#      45     learning_rate=0.001,
# ...

# %%
import tensorflow as tf
import torch  # ❌ Error: PyTorch is not installed

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Define a simple model
model = Sequential([
    Dense(32, activation='relu', input_shape=(5,)),
    Dense(1, activation='sigmoid')
])

# ❌ Error: Loss function should be a string or callable, not a number
model.compile(optimizer='adm', loss=0.5, metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 12
#       6 model = Sequential([
#       7     Dense(32, activation='relu', input_shape=(5,)),
#       8     Dense(1, activation='sigmoid')
#       9 ])
#      11 # ❌ Error: Loss function should be a string or callable, not a number
# ---> 12 model.compile(optimizer='adm', loss=0.5, metrics=['accuracy'])
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# ...

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing import image
import numpy as np

# Load the model
model = MobileNetV2(weights="imagenet", include_top=True)

# Load and preprocess the image
img_path = "flower.jpg"
img = image.load_img(img_path, target_size=224)  # ❌ Incorrect target size
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = preprocess_input(img_array)

# Make prediction
predictions = model.predict(img_array)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 11
#       9 # Load and preprocess the image
#      10 img_path = "flower.jpg"
# ---> 11 img = image.load_img(img_path, target_size=224)  # ❌ Incorrect target size
#      12 img_array = image.img_to_array(img)
#      13 img_array = np.expand_dims(img_array, axis=0)
#
# File ~\anaconda3\envs\deepL\Lib\site-packages\keras\utils\image_utils.py:443, in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     441     raise ValueError('color_mode must be "grayscale", "rgb", or "rgba"')
#     442 if target_size is not None:
# --> 443     width_height_tuple = (target_size[1], target_size[0])
#     444     if img.size != width_height_tuple:
#     445         if interpolation not in _PIL_INTERPOLATION_METHODS:
#
# TypeError: 'int' object is not subscriptable

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Define a simple model
model = Sequential([
    Dense(64, activation='relu', input_shape=(10,)),
    Dense(10, activation='softmax')
])

# Compile the model with an incorrect loss function name
model.fit(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 12
#       6 model = Sequential([
#       7     Dense(64, activation='relu', input_shape=(10,)),
#       8     Dense(10, activation='softmax')
#       9 ])
#      11 # Compile the model with an incorrect loss function name
# ---> 12 model.fit(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# ...

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense

# Model without specifying input shape
model = Sequential([
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# Model summary
model.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 11
#       5 model = Sequential([
#       6     Dense(64, activation='relu'),
#       7     Dense(10, activation='softmax')
#       8 ])
#      10 # Model summary
# ---> 11 model.summary()
#
# File ~\anaconda3\envs\deepL\Lib\site-packages\keras\engine\training.py:3229, in Model.summary(self, line_length, positions, print_fn, expand_nested, show_trainable, layer_range)
#    3198 """Prints a string summary of the network.
#    3199
#    3200 Args:
#    (...)
#    3226     ValueError: if `summary()` is called before the model is built.
#    3227 """
#    3228 if not self.built:
# -> 3229     raise ValueError(
#    3230         "This model has not yet been built. "
#    3231         "Build the model first by calling `build()` or by calling "
#    3232         "the model on a batch of data."
#    3233     )
# ...

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Generate fake training and validation data
X_train = np.random.rand(100, 10)
y_train = np.random.rand(100, 1)

X_val = np.random.rand(20, 8)  # Different feature size (error)
y_val = np.random.rand(20, 1)

# Model
model = Sequential([
    Dense(64, activation='relu', input_shape=(10,)),
    Dense(1, activation='sigmoid')
])

# Compile and train
model.compile(optimizer='adam', loss='mse')
model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=5)
# Out:
# Epoch 1/5
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 2s 872ms/step - loss: 0.1043
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 21
#      19 # Compile and train
#      20 model.compile(optimizer='adam', loss='mse')
# ---> 21 model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=5)
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# ...

# %%
import cv2

# Load image using OpenCV
img = cv2.imread('flower.jpeg')  # OpenCV loads in BGR format

# Display using Matplotlib
plt.imshow(img)
plt.show()
# Out:
# [ WARN:0@491.694] global loadsave.cpp:268 findDecoder imread_('flower.jpeg'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 7
#       4 img = cv2.imread('flower.jpeg')  # OpenCV loads in BGR format
#       6 # Display using Matplotlib
# ----> 7 plt.imshow(img)
#       8 plt.show()
#
# NameError: name 'plt' is not defined
